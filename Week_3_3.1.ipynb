# %% [markdown]
# # Week 3

# %% [markdown]
# ## 3.1	Prediction of the home prices using Multiple Linear Regression for a given dataset

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         4   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000
# 5  4100         6    8  810000

# %%
sns.lmplot(x='area',y='price',data=df)

# %%
sns.lmplot(x='bedrooms',y='price',data=df)

# %%
sns.lmplot(x='age',y='price',data=df)

# %%
reg = LinearRegression()

reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.00186540443

# %%
predicted = reg.predict([[3000,3,40]])
predicted
# Out:
# C:\Users\sures\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
reg.predict([[2500,4,5]])
# Out:
# C:\Users\sures\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %%
from sklearn.metrics import r2_score
y_original = df.price
y_original
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
y_predicted = reg.predict(df[['area','bedrooms','age']])
y_predicted
# Out:
# array([518217.63297611, 602590.07937407, 615307.4140366 , 597962.89583192,
#        760663.42675457, 795258.55102673])

# %%
r_squ = r2_score(y_original,y_predicted)
r_squ
# Out:
# 0.9550196399325819
